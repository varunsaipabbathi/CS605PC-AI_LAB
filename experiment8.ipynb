# %% [markdown]
# <a href="https://colab.research.google.com/github/varunsaipabbathi/CS605PC-AI_LAB/blob/main/experiment8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def TowerOfHanoi(n, fromRod, toRod, auxRod):
    if n == 0:
        return
    TowerOfHanoi(n-1, fromRod, auxRod, toRod)
    print("Disk", n, " moved from ", fromRod, " to ", toRod)
    TowerOfHanoi(n-1, auxRod, toRod, fromRod)

if __name__ == "__main__":
    n = 3

    # A, C, B are the name of rods
    TowerOfHanoi(n, 'A', 'C', 'B')
# Out:
# Disk 1  moved from  A  to  C
# Disk 2  moved from  A  to  B
# Disk 1  moved from  C  to  B
# Disk 3  moved from  A  to  C
# Disk 1  moved from  B  to  A
# Disk 2  moved from  B  to  C
# Disk 1  moved from  A  to  C
